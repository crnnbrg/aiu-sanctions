# %% [markdown]
# # Lifetime Ban

# %%
import pandas as pd
df = pd.read_csv('lifetime_ban.csv')

# %% [markdown]
# ## Total

# %%
len(df)
# Out:
# 53

# %% [markdown]
# ## Per nationality

# %%
nationality_count = df["Nationality"].value_counts()
print(nationality_count)
# Out:
# Nationality
# TUR    11
# RUS     8
# UKR     4
# BRA     3
# ROU     3
# BLR     2
# BUL     2
# CHN     2
# GRE     2
# NGR     2
# SVK     2
# AFG     1
# ESP     1
# FRA     1
# IND     1
# IRQ     1
# JAM     1
# KAZ     1
# KEN     1
# RSA     1
# SYR     1
# USA     1
# Name: count, dtype: int64
