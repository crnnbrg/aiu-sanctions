# %% [markdown]
# # Lifetime Ban

# %%
import pandas as pd
df = pd.read_csv('data/lifetime_ban.csv')

# %% [markdown]
# ## Total

# %%
len(df)
# Out:
# 63

# %% [markdown]
# ## Per nationality

# %%
df["Country Name"].value_counts().head(3)
# Out:
# Country Name
# Türkiye    12
# Russia      9
# China       8
# Name: count, dtype: int64

# %% [markdown]
# ## Discipline distribution

# %%
df.groupby('Country Name')['Discipline 1'].nunique().nlargest(5)
# Out:
# Country Name
# Russia      5
# Ukraine     4
# Belarus     2
# Brazil      2
# Bulgaria    2
# Name: Discipline 1, dtype: int64

# %%
df.groupby('Country Name')['Discipline 2'].nunique().nlargest(5)
# Out:
# Country Name
# Russia      4
# Brazil      3
# Türkiye     3
# Ukraine     3
# Bulgaria    2
# Name: Discipline 2, dtype: int64

# %% [markdown]
# ## Role

# %%
df.groupby("Country Name")["Role"].value_counts()
# Out:
# Country Name   Role
# Afghanistan    Athlete                       1
# Belarus        Athlete                       2
# Brazil         Athlete                       3
# Bulgaria       Athlete                       2
# China          Athlete Support Personnel     6
#                Athlete                       2
# France         Athlete                       1
# Greece         Athlete Support Personnel     1
#                Athlete                       1
# India          Athlete                       1
# Iraq           Athlete                       1
# Jamaica        Athlete                       1
# Kazakhstan     Athlete                       1
# Kenya          Athlete                       2
# Nigeria        Athlete                       2
# Romania        Athlete                       3
# Russia         Athlete                       9
# Slovakia       Athlete                       2
# South Africa   Athlete                       1
# Spain          Athlete                       1
# Syria          Athlete                       1
# Türkiye        Athlete                      12
# Ukraine        Athlete                       4
# United States  Athlete Support Personnel     1
#                Athlete                       1
# not found      Athlete                       1
# Name: count, dtype: int64

# %%
df["Role"].value_counts()
# Out:
# Role
# Athlete                      55
# Athlete Support Personnel     8
# Name: count, dtype: int64

# %%
df["ADRV Notes"].value_counts().head(3)
# Out:
# ADRV Notes
# stanozolol                                                                                        8
# administration or attempted administration to any athlete of a prohibited substance/ or method    8
# metenolone                                                                                        3
# Name: count, dtype: int64
