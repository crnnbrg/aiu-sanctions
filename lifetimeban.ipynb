# %% [markdown]
# # Lifetime Ban

# %%
import pandas as pd
df = pd.read_csv('data/lifetime_ban.csv')

# %% [markdown]
# ## Total

# %%
len(df)
# Out:
# 63

# %% [markdown]
# ## Per nationality

# %%
df["Nationality"].value_counts()
# Out:
# Nationality
# TUR    12
# RUS     9
# CHN     8
# UKR     4
# ROU     3
# BRA     3
# BUL     2
# NGR     2
# SVK     2
# KEN     2
# BLR     2
# GRE     2
# USA     2
# SYR     1
# AFG     1
# IRQ     1
# JAM     1
# ESP     1
# FRA     1
# IND     1
# KAZ     1
# RSA     1
# Name: count, dtype: int64

# %% [markdown]
# ## Role

# %%
df.groupby("Nationality")["Role"].value_counts()
# Out:
# Nationality  Role
# AFG          Athlete                       1
# BLR          Athlete                       2
# BRA          Athlete                       3
# BUL          Athlete                       2
# CHN          Athlete Support Personnel     6
#              Athlete                       2
# ESP          Athlete                       1
# FRA          Athlete                       1
# GRE          Athlete Support Personnel     1
#              Athlete                       1
# IND          Athlete                       1
# IRQ          Athlete                       1
# JAM          Athlete                       1
# KAZ          Athlete                       1
# KEN          Athlete                       2
# NGR          Athlete                       2
# ROU          Athlete                       3
# RSA          Athlete                       1
# RUS          Athlete                       9
# SVK          Athlete                       2
# ...

# %%
df["Role"].value_counts()
# Out:
# Role
# Athlete                      55
# Athlete Support Personnel     8
# Name: count, dtype: int64
