# %%
import pandas as pd
df = pd.read_csv('data/occurrence_per_nationality.csv')

# %% [markdown]
# ## Occurrences per nationality

# %%
df.nlargest(10, 'Count')[['Country Name', 'Count']]
# Out:
#     Country Name  Count
# 0          Kenya    141
# 1          India    137
# 2         Russia     74
# 3          China     31
# 4   South Africa     21
# 5          Italy     20
# 6        Türkiye     19
# 7       Ethiopia     17
# 8        Ukraine     17
# 9  United States     15

# %% [markdown]
# ## Countries per continent

# %%
df.groupby('Continent').size().nlargest(6)
# Out:
# Continent
# Asia             22
# Europe           19
# Africa           13
# South America     9
# North America     7
# Oceania           1
# dtype: int64

# %% [markdown]
# ## Occurences per continent

# %%
df.groupby('Continent')['Count'].sum().nlargest(6)
# Out:
# Continent
# Asia             251
# Africa           221
# Europe           158
# North America     26
# South America     23
# Oceania            2
# Name: Count, dtype: int64
